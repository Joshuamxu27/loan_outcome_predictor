# %%
from sqlalchemy import create_engine
import pandas as pd

engine = create_engine('postgresql://joshuaxu@localhost:5432/loans_db')

df = pd.read_sql("SELECT * FROM loans LIMIT 10000", engine)

# %%
pd.set_option('display.max_columns', None)
print(df.isnull().sum())
# Out:
# id                           0
# member_id                10000
# loan_amnt                    0
# funded_amnt                  0
# funded_amnt_inv              0
#                          ...
# settlement_status         9966
# settlement_date           9966
# settlement_amount         9966
# settlement_percentage     9966
# settlement_term           9966
# Length: 151, dtype: int64

# %%
pd.set_option('display.max_rows', None)
counts = df['emp_title'].value_counts()
print(counts[counts>1])
# Out:
# emp_title
# Teacher                             208
# Owner                               205
# Manager                             179
# Driver                               82
# Supervisor                           71
# Sales                                69
# RN                                   62
# Project Manager                      58
# Office Manager                       55
# President                            54
# Registered Nurse                     50
# owner                                49
# General Manager                      42
# Director                             40
# CEO                                  33
# Operations Manager                   31
# Accountant                           30
# manager                              30
# driver                               30
# Attorney                             29
# Truck Driver                         29
# Mechanic                             28
# Engineer                             27
# ...

# %%
print(df['issue_d'])
# Out:
# 0       Dec-2017
# 1       Dec-2017
# 2       Dec-2017
# 3       Dec-2017
# 4       Dec-2017
# 5       Dec-2017
# 6       Dec-2017
# 7       Dec-2017
# 8       Dec-2017
# 9       Dec-2017
# 10      Dec-2017
# 11      Dec-2017
# 12      Dec-2017
# 13      Dec-2017
# 14      Dec-2017
# 15      Dec-2017
# 16      Dec-2017
# 17      Dec-2017
# 18      Dec-2017
# 19      Dec-2017
# 20      Dec-2017
# 21      Dec-2017
# 22      Dec-2017
# 23      Dec-2017
# 24      Dec-2017
# 25      Dec-2017
# 26      Dec-2017
# 27      Dec-2017
# 28      Dec-2017
# 29      Dec-2017
# 30      Dec-2017
# 31      Dec-2017
# 32      Dec-2017
# 33      Dec-2017
# 34      Dec-2017
# 35      Dec-2017
# 36      Dec-2017
# 37      Dec-2017
# 38      Dec-2017
# 39      Dec-2017
# 40      Dec-2017
# 41      Dec-2017
# 42      Dec-2017
# 43      Dec-2017
# 44      Dec-2017
# 45      Dec-2017
# 46      Dec-2017
# 47      Dec-2017
# 48      Dec-2017
# 49      Dec-2017
# 50      Dec-2017
# 51      Dec-2017
# ...

# %%
temp_df = pd.read_parquet('../data/ML_training_data/model_training_cleaned.parquet')

temp_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6537 entries, 0 to 6536
# Data columns (total 29 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   loan_amnt             6537 non-null   float64
#  1   int_rate              6537 non-null   str
#  2   installment           6537 non-null   float64
#  3   sub_grade             6537 non-null   str
#  4   purpose               6537 non-null   str
#  5   addr_state            6537 non-null   str
#  6   annual_inc            6537 non-null   float64
#  7   home_ownership        6537 non-null   str
#  8   verification_status   6537 non-null   str
#  9   effective_dti         6537 non-null   str
#  10  is_joint              6537 non-null   int64
#  11  fico_score            6537 non-null   str
#  12  revol_util            6530 non-null   str
#  13  revol_bal             6537 non-null   float64
#  14  open_acc              6535 non-null   float64
# ...
