# %%
from sqlalchemy import create_engine
import pandas as pd

engine = create_engine('postgresql://joshuaxu@localhost:5432/loans_db')

df = pd.read_sql("SELECT * FROM loans LIMIT 10000", engine)

df.head(20)
# Out:
#           id member_id loan_amnt funded_amnt funded_amnt_inv        term  \
# 0   68407277      None    3600.0      3600.0          3600.0   36 months
# 1   68355089      None   24700.0     24700.0         24700.0   36 months
# 2   68341763      None   20000.0     20000.0         20000.0   60 months
# 3   66310712      None   35000.0     35000.0         35000.0   60 months
# 4   68476807      None   10400.0     10400.0         10400.0   60 months
# 5   68426831      None   11950.0     11950.0         11950.0   36 months
# 6   68476668      None   20000.0     20000.0         20000.0   36 months
# 7   67275481      None   20000.0     20000.0         20000.0   36 months
# 8   68466926      None   10000.0     10000.0         10000.0   36 months
# 9   68616873      None    8000.0      8000.0          8000.0   36 months
# 10  68356421      None   22400.0     22400.0         22400.0   60 months
# 11  68426545      None   16000.0     16000.0         16000.0   60 months
# 12  68338832      None    1400.0      1400.0          1400.0   36 months
# 13  66624733      None   18000.0     18000.0         18000.0   60 months
# 14  68466961      None   28000.0     28000.0         28000.0   36 months
# 15  68354783      None    9600.0      9600.0          9600.0   36 months
# 16  68466916      None   25000.0     25000.0         25000.0   36 months
# 17  68577849      None   18000.0     18000.0         18000.0   60 months
# 18  68506798      None   23000.0     23000.0         23000.0   60 months
# 19  68495092      None    8650.0      8650.0          8650.0   36 months
#
#    int_rate installment grade sub_grade  ... hardship_payoff_balance_amount  \
# 0     13.99      123.03     C        C4  ...                            NaN
# 1     11.99      820.28     C        C1  ...                            NaN
# 2     10.78      432.66     B        B4  ...                            NaN
# 3     14.85       829.9     C        C5  ...                            NaN
# 4     22.45      289.91     F        F1  ...                            NaN
# 5     13.44      405.18     C        C3  ...                            NaN
# 6      9.17      637.58     B        B2  ...                            NaN
# 7      8.49      631.26     B        B1  ...                            NaN
# 8      6.49      306.45     A        A2  ...                            NaN
# 9     11.48      263.74     B        B5  ...                            NaN
# 10    12.88       508.3     C        C2  ...                            NaN
# 11    12.88      363.07     C        C2  ...                            NaN
# 12    12.88        47.1     C        C2  ...                            NaN
# 13    19.48       471.7     E        E2  ...                            NaN
# 14     6.49      858.05     A        A2  ...                            NaN
# 15     7.49      298.58     A        A4  ...                            NaN
# 16     7.49      777.55     A        A4  ...                            NaN
# 17    11.99      400.31     C        C1  ...                            NaN
# 18     8.49      471.77     B        B1  ...                            NaN
# 19    19.89      320.99     E        E3  ...                            NaN
#
#    hardship_last_payment_amount disbursement_method debt_settlement_flag  \
# 0                           NaN                Cash                    N
# 1                           NaN                Cash                    N
# 2                           NaN                Cash                    N
# 3                           NaN                Cash                    N
# 4                           NaN                Cash                    N
# 5                           NaN                Cash                    N
# 6                           NaN                Cash                    N
# 7                           NaN                Cash                    N
# 8                           NaN                Cash                    N
# 9                           NaN                Cash                    N
# 10                          NaN                Cash                    N
# 11                          NaN                Cash                    N
# 12                          NaN                Cash                    N
# 13                          NaN                Cash                    N
# 14                          NaN                Cash                    N
# 15                          NaN                Cash                    N
# 16                          NaN                Cash                    N
# 17                          NaN                Cash                    N
# 18                          NaN                Cash                    N
# 19                          NaN                Cash                    N
#
#    debt_settlement_flag_date settlement_status settlement_date  \
# 0                        NaN               NaN             NaN
# 1                        NaN               NaN             NaN
# 2                        NaN               NaN             NaN
# 3                        NaN               NaN             NaN
# 4                        NaN               NaN             NaN
# 5                        NaN               NaN             NaN
# 6                        NaN               NaN             NaN
# 7                        NaN               NaN             NaN
# 8                        NaN               NaN             NaN
# 9                        NaN               NaN             NaN
# 10                       NaN               NaN             NaN
# 11                       NaN               NaN             NaN
# 12                       NaN               NaN             NaN
# 13                       NaN               NaN             NaN
# 14                       NaN               NaN             NaN
# 15                       NaN               NaN             NaN
# 16                       NaN               NaN             NaN
# 17                       NaN               NaN             NaN
# 18                       NaN               NaN             NaN
# 19                       NaN               NaN             NaN
#
#    settlement_amount settlement_percentage settlement_term
# 0                NaN                   NaN             NaN
# 1                NaN                   NaN             NaN
# 2                NaN                   NaN             NaN
# 3                NaN                   NaN             NaN
# 4                NaN                   NaN             NaN
# 5                NaN                   NaN             NaN
# 6                NaN                   NaN             NaN
# 7                NaN                   NaN             NaN
# 8                NaN                   NaN             NaN
# 9                NaN                   NaN             NaN
# 10               NaN                   NaN             NaN
# 11               NaN                   NaN             NaN
# 12               NaN                   NaN             NaN
# 13               NaN                   NaN             NaN
# 14               NaN                   NaN             NaN
# 15               NaN                   NaN             NaN
# 16               NaN                   NaN             NaN
# 17               NaN                   NaN             NaN
# 18               NaN                   NaN             NaN
# 19               NaN                   NaN             NaN
#
# [20 rows x 151 columns]

# %%
df.iloc[:20,9:30]
# Out:
#    sub_grade                                emp_title emp_length  \
# 0         C4                                  leadman  10+ years
# 1         C1                                 Engineer  10+ years
# 2         B4                             truck driver  10+ years
# 3         C5              Information Systems Officer  10+ years
# 4         F1                      Contract Specialist    3 years
# 5         C3                     Veterinary Tecnician    4 years
# 6         B2  Vice President of Recruiting Operations  10+ years
# 7         B1                              road driver  10+ years
# 8         A2                          SERVICE MANAGER    6 years
# 9         B5                           Vendor liaison  10+ years
# 10        C2                       Executive Director    6 years
# 11        C2               Senior Structural Designer     1 year
# 12        C2                        Logistics Manager    3 years
# 13        E2                         Software Manager    7 years
# 14        A2                           Senior Manager  10+ years
# 15        A4                                     tech    8 years
# 16        A4                            Sales Manager  10+ years
# 17        C1                                    GS-11  10+ years
# 18        B1                                  Teacher    5 years
# 19        E3                     Program Coordinator     8 years
#
#    home_ownership annual_inc verification_status   issue_d  loan_status  \
# 0        MORTGAGE    55000.0        Not Verified  Dec-2015   Fully Paid
# 1        MORTGAGE    65000.0        Not Verified  Dec-2015   Fully Paid
# 2        MORTGAGE    63000.0        Not Verified  Dec-2015   Fully Paid
# 3        MORTGAGE   110000.0     Source Verified  Dec-2015      Current
# 4        MORTGAGE   104433.0     Source Verified  Dec-2015   Fully Paid
# 5            RENT    34000.0     Source Verified  Dec-2015   Fully Paid
# 6        MORTGAGE   180000.0        Not Verified  Dec-2015   Fully Paid
# 7        MORTGAGE    85000.0        Not Verified  Dec-2015   Fully Paid
# 8            RENT    85000.0        Not Verified  Dec-2015   Fully Paid
# 9        MORTGAGE    42000.0        Not Verified  Dec-2015   Fully Paid
# 10       MORTGAGE    95000.0        Not Verified  Dec-2015      Current
# 11       MORTGAGE    70000.0        Not Verified  Dec-2015      Current
# 12       MORTGAGE    64000.0        Not Verified  Dec-2015   Fully Paid
# 13           RENT   150000.0        Not Verified  Dec-2015  Charged Off
# 14       MORTGAGE    92000.0        Not Verified  Dec-2015   Fully Paid
# 15       MORTGAGE    60000.0        Not Verified  Dec-2015   Fully Paid
# 16       MORTGAGE   109000.0        Not Verified  Dec-2015   Fully Paid
# 17       MORTGAGE   112000.0        Not Verified  Dec-2015   Fully Paid
# 18           RENT    64000.0        Not Verified  Dec-2015      Current
# 19           RENT    55000.0            Verified  Dec-2015   Fully Paid
#
#    pymnt_plan                                                url  ...  \
# 0           n  https://lendingclub.com/browse/loanDetail.acti...  ...
# 1           n  https://lendingclub.com/browse/loanDetail.acti...  ...
# 2           n  https://lendingclub.com/browse/loanDetail.acti...  ...
# 3           n  https://lendingclub.com/browse/loanDetail.acti...  ...
# 4           n  https://lendingclub.com/browse/loanDetail.acti...  ...
# 5           n  https://lendingclub.com/browse/loanDetail.acti...  ...
# 6           n  https://lendingclub.com/browse/loanDetail.acti...  ...
# 7           n  https://lendingclub.com/browse/loanDetail.acti...  ...
# 8           n  https://lendingclub.com/browse/loanDetail.acti...  ...
# 9           n  https://lendingclub.com/browse/loanDetail.acti...  ...
# 10          n  https://lendingclub.com/browse/loanDetail.acti...  ...
# 11          n  https://lendingclub.com/browse/loanDetail.acti...  ...
# 12          n  https://lendingclub.com/browse/loanDetail.acti...  ...
# 13          n  https://lendingclub.com/browse/loanDetail.acti...  ...
# 14          n  https://lendingclub.com/browse/loanDetail.acti...  ...
# 15          n  https://lendingclub.com/browse/loanDetail.acti...  ...
# 16          n  https://lendingclub.com/browse/loanDetail.acti...  ...
# 17          n  https://lendingclub.com/browse/loanDetail.acti...  ...
# 18          n  https://lendingclub.com/browse/loanDetail.acti...  ...
# 19          n  https://lendingclub.com/browse/loanDetail.acti...  ...
#
#                purpose                    title zip_code addr_state    dti  \
# 0   debt_consolidation       Debt consolidation    190xx         PA   5.91
# 1       small_business                 Business    577xx         SD  16.06
# 2     home_improvement                      NaN    605xx         IL  10.78
# 3   debt_consolidation       Debt consolidation    076xx         NJ  17.06
# 4       major_purchase           Major purchase    174xx         PA  25.37
# 5   debt_consolidation       Debt consolidation    300xx         GA   10.2
# 6   debt_consolidation       Debt consolidation    550xx         MN  14.67
# 7       major_purchase           Major purchase    293xx         SC  17.61
# 8          credit_card  Credit card refinancing    160xx         PA  13.07
# 9          credit_card  Credit card refinancing    029xx         RI   34.8
# 10  debt_consolidation       Debt consolidation    290xx         SC  22.98
# 11  debt_consolidation       Debt consolidation    786xx         TX   26.4
# 12               other                      NaN    275xx         NC  34.95
# 13  debt_consolidation       Debt consolidation    916xx         CA   9.39
# 14  debt_consolidation       Debt consolidation    275xx         NC   21.6
# 15         credit_card  Credit card refinancing    299xx         SC  22.44
# 16  debt_consolidation       Debt consolidation    226xx         VA  26.02
# 17  debt_consolidation       Debt consolidation    856xx         AZ   8.68
# 18         credit_card  Credit card refinancing    117xx         NY  18.28
# 19  debt_consolidation       Debt consolidation    462xx         IN  25.49
#
#    delinq_2yrs earliest_cr_line fico_range_low fico_range_high inq_last_6mths
# 0          0.0         Aug-2003          675.0           679.0            1.0
# 1          1.0         Dec-1999          715.0           719.0            4.0
# 2          0.0         Aug-2000          695.0           699.0            0.0
# 3          0.0         Sep-2008          785.0           789.0            0.0
# 4          1.0         Jun-1998          695.0           699.0            3.0
# 5          0.0         Oct-1987          690.0           694.0            0.0
# 6          0.0         Jun-1990          680.0           684.0            0.0
# 7          1.0         Feb-1999          705.0           709.0            0.0
# 8          0.0         Apr-2002          685.0           689.0            1.0
# 9          0.0         Nov-1994          700.0           704.0            0.0
# 10         0.0         Apr-1995          710.0           714.0            0.0
# 11         0.0         Feb-1988          720.0           724.0            0.0
# 12         0.0         Jun-1996          700.0           704.0            0.0
# 13         0.0         Jun-2005          665.0           669.0            1.0
# 14         0.0         May-1984          720.0           724.0            0.0
# 15         0.0         Jun-1996          695.0           699.0            0.0
# 16         0.0         Dec-2001          745.0           749.0            1.0
# 17         0.0         Nov-1993          800.0           804.0            0.0
# 18         0.0         Sep-2001          700.0           704.0            0.0
# 19         0.0         Mar-2005          675.0           679.0            4.0
#
# [20 rows x 21 columns]
